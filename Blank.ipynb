# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import geopandas as gp

# %%
pnw = gp.GeoDataFrame.from_file('WBDSnapshot_National_HUC12_R17.shp')
pnw.head()
# Out:
#          HUC_12  SUM_NCONTR FIRST_HU_1    FIRST_HU_2              FIRST_HU_3  \
# 0  170101010201         0.0             170101010204  Swamp Creek-Lake Creek
# 1  170101010202         0.0             170101010204     Upper Fortine Creek
# 2  170101010203         0.0             170101010204              Edna Creek
# 3  170101010204         0.0             170101010207    Middle Fortine Creek
# 4  170101010205         0.0             170101010207              Deep Creek
#
#   FIRST_HU_4 FIRST_HU_5                                           geometry
# 0         NM          S  POLYGON ((-115.0069057789999 48.65497107900006...
# 1         NM          S  POLYGON ((-114.8864817459999 48.55537782700009...
# 2         NM          S  POLYGON ((-114.9677057409999 48.69637374700005...
# 3         NM          S  POLYGON ((-114.8110693239999 48.63353546100006...
# 4         NM          S  POLYGON ((-114.7325683969999 48.80957420300007...

# %%
pnw.plot()

# %%
hhdw1_elev_bands = gp.GeoDataFrame.from_file('hhdw1_elev_bands.shp')
#hhdw1_elev_bands.head()

# %%
hhdw1_elev_bands.plot(column='AREA_SQMI')

# %%
hhdw1_lump = gp.GeoDataFrame.from_file('hhdw1_lump.shp')
#hhdw1_lump.head()

# %%
hhdw1_lump.plot()

# %%
hhdw1_lump
# Out:
#      LID   Area_sqmi  Shape_Leng  Shape_Area CWA CH5_ID NAME RFC DESCRIPTIO  \
# 0  HHDW1  214.192719    1.686244    0.065892
#
#   TYPE                        ...                         ZONE_1_SHE  \
# 0                             ...
#
#   ZONE_2_SHE  ZONE_3_SHE ZONE_4_SHE  Mean_ELEV_       Lat         Lon  \
# 0                                           0.0  47.22987 -121.561549
#
#    x_centroid y_centroid                                           geometry
# 0 -121.561549   47.22987  POLYGON ((-121.781687499955 47.28291666685811,...
#
# [1 rows x 28 columns]
